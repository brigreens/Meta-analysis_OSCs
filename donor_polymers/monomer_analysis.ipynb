# %% [markdown]
# This notebook will help examine different donor-polymer monomers and which type appears the most in top pairs.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

SMALL_SIZE = 12
MEDIUM_SIZE = 16
BIGGER_SIZE = 20

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=MEDIUM_SIZE)  # fontsize of the figure title
plt.rcParams['legend.title_fontsize'] = 'x-large' # fontsize of legend title

sns.set_style("white")

# %%
df = pd.read_csv("don_monomer_smarts.csv")
df["mons_count"] = df["A_count"].astype(str) + df["B_count"].astype(str) + df["C_count"].astype(str) + df["D_count"].astype(str) + df["E_count"].astype(str) + df["F_count"].astype(str) + df["G_count"].astype(str) + df["H_count"].astype(str) + df["I_count"].astype(str) + df["J_count"].astype(str) + df["K_count"].astype(str) + df["L_count"].astype(str)

# %%
mon_string_counts = df["mons_count"].value_counts()
mons_df = pd.DataFrame({'mon': mon_string_counts.index, 'count': mon_string_counts})
top_mons = mons_df[:10]
print(top_mons)

sns.catplot(data = top_mons, x = "mon", y="count", kind="bar", palette="rocket")

plt.xlabel("Monomers")
plt.ylabel("Count")
plt.grid(alpha=0.5)
plt.xticks(rotation=45, ha='right')
plt.title("Most common monomers for any PCE")

plt.tight_layout()
#plt.savefig('common_monomers_barplot_anyPCE.pdf', dpi=600)
plt.savefig('common_monomers_barplot_anyPCE.png', dpi=600)

plt.show()
# Out:
#                        mon  count
# 110000000000  110000000000    979
# 100001000000  100001000000    203
# 101000000000  101000000000    192
# 000000000000  000000000000    162
# 100000000000  100000000000    152
# 000010000000  000010000000     44
# 100000100000  100000100000     41
# 100000001000  100000001000     26
# 100010000000  100010000000     25
# 100000010000  100000010000     23

# %% [markdown]
# The format is one-hot encoded in the order A, B, C, D, E, F, G, H, I, J, K, and L. Monomer A is  benzodithiophene (BDT), Monomer B is benzodithiophenedione (BDD), Monomer C is benzotriazole (BTA), Monomer D is benzothiadiazole, Monomer E is quinoxaline (Qx), Monomer F is thieno[3,4-b]thiophene (TT), Monomer G is dithienobenzothiadiazole (DTBT), Monomer H is an imide-fused benzotriazole (TzBI), Monomer I is thieno[3,4-c]pyrrole-4,6-dione (TPD), Monomer J is Dithienoquinoxaline (DTQx), Monomer K is thiazolo[5,4-d]thiazole, Monomer L is benzo[1,2-b:4,5-b']difuran (BDF)

# %% [markdown]
# Lets see how this changes for PCE above 10, 15, an 17%.

# %%
PCE_above10 = df[df["PCE_avg"] > 10]

mon_string_counts = PCE_above10["mons_count"].value_counts()
mons_df = pd.DataFrame({'mon': mon_string_counts.index, 'count': mon_string_counts})

top_mons = mons_df[:10]

sns.catplot(data = top_mons, x = "mon", y="count", kind="bar", palette="rocket")
plt.xlabel("Monomers")
plt.ylabel("Count")

plt.grid(alpha=0.5)
plt.xticks(rotation=45, ha='right')

plt.title("Most common monomers for PCE > 10%")

plt.tight_layout()

#plt.savefig('common_monomers_barplot_PCEabove10.pdf', dpi=600)
plt.savefig('common_monomers_barplot_PCEabove10.png', dpi=600)

plt.show()

# %%
PCE_above15 = df[df["PCE_avg"] > 15]


mon_string_counts = PCE_above15["mons_count"].value_counts()
mons_df = pd.DataFrame({'mon': mon_string_counts.index, 'count': mon_string_counts})

top_mons = mons_df[:10]

sns.catplot(data = top_mons, x = "mon", y="count", kind="bar", palette="rocket")

plt.xlabel("Monomers")
plt.ylabel("Count")

plt.grid(alpha=0.5)
plt.xticks(rotation=45, ha='right')

plt.title("Most common monomers for PCE > 15%")

plt.tight_layout()

#plt.savefig('common_monomers_barplot_PCEabove15.pdf', dpi=600)
plt.savefig('common_monomers_barplot_PCEabove15.png', dpi=600)

plt.show()

# %%
PCE_above17 = df[df["PCE_avg"] > 17]


mon_string_counts = PCE_above17["mons_count"].value_counts()
mons_df = pd.DataFrame({'mon': mon_string_counts.index, 'count': mon_string_counts})

top_mons = mons_df[:10]

sns.catplot(data = top_mons, x = "mon", y="count", kind="bar", palette="rocket")

plt.xlabel("Monomers")
plt.ylabel("Count")

plt.grid(alpha=0.5)
plt.xticks(rotation=45, ha='right')

plt.title("Most common monomers for PCE > 17%")

plt.tight_layout()

#plt.savefig('common_monomers_barplot_PCEabove17.pdf', dpi=600)
plt.savefig('common_monomers_barplot_PCEabove17.png', dpi=600)

plt.show()

# %% [markdown]
# Lets see the most common donors and their frequency among the top devices

# %%
don_counts = df["don_ID"].astype(str).value_counts()
dons_df = pd.DataFrame({'don': don_counts.index, 'count': don_counts})

top_dons = dons_df[:10]

sns.catplot(data = top_dons, x = "don", y="count", kind="bar", palette="rocket")

#plt.xticks(np.arange(min(lengths)-1/2, max(lengths)+1/2, 1))
plt.xlabel("Donor ID")
plt.ylabel("Count")

plt.grid(alpha=0.5)
plt.xticks(rotation=45, ha='center')

plt.title("Most common donor polymers")

plt.tight_layout()

#plt.savefig('top_donors_barplot_anyPCE.pdf', dpi=600)
plt.savefig('top_donors_barplot_anyPCE.png', dpi=600)

plt.show()

# %%
PCE_above10 = df[df["PCE_avg"] > 10]

don_counts = PCE_above10["don_ID"].astype(str).value_counts()
dons_df = pd.DataFrame({'don': don_counts.index, 'count': don_counts})

top_dons = dons_df[:10]

sns.catplot(data = top_dons, x = "don", y="count", kind="bar", palette="rocket")

#plt.xticks(np.arange(min(lengths)-1/2, max(lengths)+1/2, 1))
plt.xlabel("Donor ID")
plt.ylabel("Count")

plt.grid(alpha=0.5)
plt.xticks(rotation=45, ha='center')

plt.title("Most common donor polymers with PCE > 10%")

plt.tight_layout()

#plt.savefig('top_donors_barplot_PCEabove10.pdf', dpi=600)
plt.savefig('top_donors_barplot_PCEabove10.png', dpi=600)

plt.show()

# %%
PCE_above15 = df[df["PCE_avg"] > 15]

don_counts = PCE_above15["don_ID"].astype(str).value_counts()
dons_df = pd.DataFrame({'don': don_counts.index, 'count': don_counts})

top_dons = dons_df[:10]

sns.catplot(data = top_dons, x = "don", y="count", kind="bar", palette="rocket")

#plt.xticks(np.arange(min(lengths)-1/2, max(lengths)+1/2, 1))
plt.xlabel("Donor ID")
plt.ylabel("Count")

plt.grid(alpha=0.5)
plt.xticks(rotation=45, ha='center')

plt.title("Most common donor polymers with PCE > 15%")

plt.tight_layout()

#plt.savefig('top_donors_barplot_PCEabove15.pdf', dpi=600)
plt.savefig('top_donors_barplot_PCEabove15.png', dpi=600)

plt.show()

# %%
PCE_above17 = df[df["PCE_avg"] > 17]
print(len(PCE_above17))

don_counts = PCE_above17["don_ID"].astype(str).value_counts()
dons_df = pd.DataFrame({'don': don_counts.index, 'count': don_counts})

top_dons = dons_df[:10]

sns.catplot(data = top_dons, x = "don", y="count", kind="bar", palette="rocket")

#plt.xticks(np.arange(min(lengths)-1/2, max(lengths)+1/2, 1))
plt.xlabel("Donor ID")
plt.ylabel("Count")

plt.grid(alpha=0.5)
plt.xticks(rotation=45, ha='center')

plt.title("Most common donor polymers with PCE > 17%")

plt.tight_layout()

#plt.savefig('top_donors_barplot_PCEabove17.pdf', dpi=600)
plt.savefig('top_donors_barplot_PCEabove17.png', dpi=600)

plt.show()
# Out:
# 69

# %%
PCE_above18 = df[df["PCE_avg"] > 18]
print(len(PCE_above18))

don_counts = PCE_above18["don_ID"].astype(str).value_counts()
dons_df = pd.DataFrame({'don': don_counts.index, 'count': don_counts})

top_dons = dons_df[:10]

sns.catplot(data = top_dons, x = "don", y="count", kind="bar", palette="rocket")

#plt.xticks(np.arange(min(lengths)-1/2, max(lengths)+1/2, 1))
plt.xlabel("Donor ID")
plt.ylabel("Count")

plt.grid(alpha=0.5)
plt.xticks(rotation=45, ha='center')

plt.title("Most common donor polymers with PCE > 18%")

plt.tight_layout()

#plt.savefig('top_donors_barplot_PCEabove18.pdf', dpi=600)
plt.savefig('top_donors_barplot_PCEabove18.png', dpi=600)

plt.show()
# Out:
# 17
